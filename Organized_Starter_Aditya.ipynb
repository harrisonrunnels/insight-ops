# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from openai import OpenAI
import json
import os
import numpy as np

# %%
def load_data(file_path):
    return pd.read_csv(file_path)


def filter_data(df, start_time, frame):
    def generate_range(start_time, frame):
        dtStart = datetime.strptime(start_time, '%Y-%m-%d %H:%M:%S')
        dtDiff = timedelta(hours=frame[0], minutes=frame[1])
        dest = dtStart + dtDiff
        return [start_time, dest.strftime('%Y-%m-%d %H:%M:%S')]
    
    time_range = generate_range(start_time, frame)
    return df[(df["time"] >= time_range[0]) & (df["time"] <= time_range[1])]

def initialize_api_client(api_key):
    return OpenAI(
        base_url="https://hackathon.radiantai.com/insight-ops/openai",
        api_key=api_key
    )

# %%
def extract_image_data(df_1, context, post_contents, image_index, api_client):
    post_orgininal = df_1['translation']
    imgs = df_1['attachment_urls'].split(",")
    print(imgs)
    if len(df_1['attachment_urls']) == 0:
        file_key = imgs[0]
    else:
        file_key = imgs[image_index]

    #Return false if the file ends with any extension that is not an image
    if not file_key.endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp', '.webp')):
        return False
    
    image_url = "https://vl-nat-sec-hackathon-may-2024.s3.amazonaws.com/" + file_key

    system_prompt = """You are a helpful assistant designed to output JSON and analyze images. This image in the user message was attached to a post. We had a program analyze the post and come up with subjects and relationships/actions between those subjects. You will be provided that data of the subjects and relationships, the context of the post to mkae sure you do not mention anything irrelevant. You need to do the following:
    Analyze the image and provide the subjects and relationships/actions between those subjects to enter into the graph database.
    MAKE SURE to output the data in a JSON format with the top level keys 'subjects' and 'relationships', 
    Every object has a title and it has a type, the title indicates the name of the subject: this can be an person or "actor", event, or even concept, just make up a classification that is very standard.
    Two objects may be related in some way and this may and in this case, you will add them to the relationships list, try to find fitting relationships between related objects. For example, if you create a relationship between a person and an event you can use the relationship "participated in" or "attended". Or if you have a person and a concept you can use "knows" or "is familiar with". Or if you have two events you can use "happened before" or "happened after". Make up a relationship.
    How you will enter it in to the graph database it as follows, only include finding from the image in this response (meaning you will output in JSON format, DO NOT OUTPUT ANYTHING ELSE, IT WILL BREAK THE WHOLE PROGRAM):
    {
        "subjects": [
        [ENTITY_ID: INT, TITLE: STR, TYPE: STR],
        [ENTITY_ID: INT, TITLE: STR, TYPE: STR],
        ...
        ],
        "relationships": [
        [ENTITY_ID_1: INT, RELATIONSHIP: STR, ENTITY_ID_2: INT, PROPERTIES: DICT],
        [ENTITY_ID_1: INT, RELATIONSHIP: STR, ENTITY_ID_2: INT, PROPERTIES: DICT],
        ...
        ]
    }
    When you find a node or relationship you want to add try to create a generic PROPERTY for it that describes the entity you can also think of it as a label.
    Include things relevant to the""", context, """. 
    Also make sure that the RELATIONSHIP is consise, if the relationship is not simple to explain, it may not be relevant to the context of the""", context, """and should be left out. Analyze the image in keeping in mind the similarity and relevance of it to the QUALITIES OF THE PREVIOUS MOST HERE: """, str(json.dumps(post_contents)) , """and provide the JSON response, remember to look at the subjects of the post it is attached to, if there is something potentially related to a subject in the post, include it in the response. Here is the original post:""", post_orgininal, """"""
    print(image_url)
    response = api_client.chat.completions.create(
        model='gpt-4-vision-preview',
        messages=[
            {'role': 'system', 'content': system_prompt},
            {'role': 'user', 'content': [{'type': 'image_url', 'image_url': {'url': image_url}}]}
        ]
    )
  
    return json.loads("".join((response.choices[0].message.content).split("\n")[1:-1]))

def process_post(post, api_client):
    
    system_prompt = """You are a helpful assistant designed to output JSON.
Your task is to extract information from social media posts or announcements relevant to the Ukraine Russian war and convert it into a graph database.

Here is how the graph database works:
Every object has a title and it has a type, the title indicates the name of the subject: this can be an person or "actor", event, or even concept, just make up a classification that is very standard.
Two objects may be related in some way and this may and in this case, you will add them to the relationships list, try to find fitting relationships between related objects. For example, if you create a relationship between a person and an event you can use the relationship "participated in" or "attended". Or if you have a person and a concept you can use "knows" or "is familiar with". Or if you have two events you can use "happened before" or "happened after". Make up a relationship.
How you will enter it in to the graph database it as follows:
{
  "subjects": [
    [ENTITY_ID: INT, TITLE: STR, TYPE: STR],
    [ENTITY_ID: INT, TITLE: STR, TYPE: STR],
    ...
  ],
  "relationships": [
    [ENTITY_ID_1: (ANY), RELATIONSHIP: STR, ENTITY_ID_2: (ANY), PROPERTIES: DICT],
    [ENTITY_ID_1: (ANY), RELATIONSHIP: STR, ENTITY_ID_2: (ANY), PROPERTIES: DICT],
    ...
  ]
}
If you can't pair a relationship with a pair of nodes don't add it.
When you find a node or relationship you want to add try to create a generic PROPERTY for it that describes the entity you can also think of it as a label.
Only include things relevant to the Ukraine Russia conflict
One more thing: this image IS ATTACHED TO A POST, so try to find a relationship between the image subjects and the post subjects. This image needs to add to the actual post subjects and relationships, as it is attached to the post."""

    
    response = api_client.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        response_format={"type": "json_object"},
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": f"Here's the post: {post} \\n Make sure to output in a JSON with the top level keys 'subjects' and 'relationships'"}
        ]
    )
    return json.loads(response.choices[0].message.content)


def extract_graph_data(df, api_client):
    """
    Iterate over a DataFrame of posts, process each one, and accumulate the graph data.
    
    Args:
    df (pandas.DataFrame): DataFrame containing the posts to process.
    api_client (OpenAI.Client): The API client instance.
    
    Returns:
    dict: A dictionary containing accumulated nodes and edges from all posts.
    """
    system_prompt = "Your task is to extract information from social media posts and convert it into a graph database."
    all_data = {'subjects': [], 'relationships': []}  # Initialize structure to hold combined data from all posts
    
    img_data = {}

    image_data = []

    for index, row in df.iterrows():
        
        post_data = process_post(row['translation'], api_client)

        image_data = []
        for i in range(len(row["attachment_urls"].split(","))):
            try:
                image_1 = extract_image_data(row, "Russia vs. Ukraine", post_data, i, api_client)
            except:
                image_1 = False
            if image_1:
                image_data.append(image_1)
                post_data['subjects'].extend(image_1['subjects'])
                post_data['relationships'].extend(image_1['relationships'])
        
        try:
            for x in post_data['subjects']:
                x[0] = row['id'] + '_' + str(x[0])

            for x in post_data['relationships']:
                x[0] = row['id'] + '_' + str(x[0])
                x[2] = row['id'] + '_' + str(x[2])
        except:
            continue
        else:
            all_data['subjects'].extend(post_data['subjects'])
            all_data['relationships'].extend(post_data['relationships'])
    
    return all_data

# %%
'''

def deduping_nodes(nodes, api_client):
    
    system_prompt = """You are a helpful assistant designed to do data disambiguation nodes from a knowledge graph about the Russia Ukraine war.

Here is how the graph database works:
Every object has a title and it has a type, the title indicates the name of the subject
The input is a list of lists and this is what the input looks like:
[
    [ENTITY_ID: INT, TITLE: STR, TYPE: STR],
    [ENTITY_ID: INT, TITLE: STR, TYPE: STR],
    ...
  ]

You have to output a list of tuples for the titles that are different entries in the list but actually represent the same entity.

Example of entities that are the same could be [(Russian Army, Russian Armed Forces)]"""

system_prompt = """Your task is to identify if there are duplicated nodes in a noisy knowledge graph 
    
You will be given a datasets of nodes and some of these nodes may be duplicated or refer to the same entity. 
The datasets contains nodes in the form [ENTITY_ID, ENTITY_NAME, TYPE]. 

There are many duplicates in this dataset with slightly different phraseology for the ENTITY_NAME

When you have completed your task please give me the pairwise entities that are reasonably the duplicate entities. 

The output should be in the format [(a,b)] 
"""
    response = api_client.chat.completions.create(
        model="gpt-3.5-turbo-0125",
        response_format={"type": "json_object"},
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": f"Here's the input: {nodes}. Make sure the output is in JSON \\n"}
        ]
    )
    return json.loads(response.choices[0].message.content)

deduped = deduping_nodes(structured_data["subjects"][:20], api_client)
deduped
'''
# Out:
# '\n\ndef deduping_nodes(nodes, api_client):\n    \n    system_prompt = """You are a helpful assistant designed to do data disambiguation nodes from a knowledge graph about the Russia Ukraine war.\n\nHere is how the graph database works:\nEvery object has a title and it has a type, the title indicates the name of the subject\nThe input is a list of lists and this is what the input looks like:\n[\n    [ENTITY_ID: INT, TITLE: STR, TYPE: STR],\n    [ENTITY_ID: INT, TITLE: STR, TYPE: STR],\n    ...\n  ]\n\nYou have to output a list of tuples for the titles that are different entries in the list but actually represent the same entity.\n\nExample of entities that are the same could be [(Russian Army, Russian Armed Forces)]"""\n\nsystem_prompt = """Your task is to identify if there are duplicated nodes in a noisy knowledge graph \n    \nYou will be given a datasets of nodes and some of these nodes may be duplicated or refer to the same entity. \nThe datasets contains nodes in the form [ENTITY_ID, ENTITY_NAME, TYPE]. \n\nThere are many duplicates in this dataset with slightly different phraseology for the ENTITY_NAME\n\nWhen you have completed your task please give me the pairwise entities that are reasonably the duplicate entities. \n\nThe output should be in the format [(a,b)] \n"""\n    response = api_client.chat.completions.create(\n        model="gpt-3.5-turbo-0125",\n        response_format={"type": "json_object"},\n        messages=[\n            {"role": "system", "content": system_prompt},\n            {"role": "user", "content": f"Here\'s the input: {nodes}. Make sure the output is in JSON \\n"}\n        ]\n    )\n    return json.loads(response.choices[0].message.content)\n\ndeduped = deduping_nodes(structured_data["subjects"][:20], api_client)\ndeduped\n'

# %%
api_key = os.environ["HACKATHON_API_KEY"]
df = load_data('data/russia_social_media.csv')

# %%
filtered_df = filter_data(df, "2024-03-31 18:00:00", [0, 1]).head(3)
api_client = initialize_api_client(api_key)
filtered_df.shape
# Out:
# (3, 9)

# %%
# %%time
abc = extract_graph_data(filtered_df, api_client)
print(abc)
# Out:
# ['media/telegram-web/ac680058-eeda-41f0-b65d-6971cc3e831e.jpeg']
# https://vl-nat-sec-hackathon-may-2024.s3.amazonaws.com/media/telegram-web/ac680058-eeda-41f0-b65d-6971cc3e831e.jpeg
# ['media/telegram-web/7447129d-96cc-4d63-b0f5-991f65238c13.jpeg']
# https://vl-nat-sec-hackathon-may-2024.s3.amazonaws.com/media/telegram-web/7447129d-96cc-4d63-b0f5-991f65238c13.jpeg
# ['media/telegram-web/867b1e01-2e49-400e-b809-4cc0e91aeb4d.jpeg']
# https://vl-nat-sec-hackathon-may-2024.s3.amazonaws.com/media/telegram-web/867b1e01-2e49-400e-b809-4cc0e91aeb4d.jpeg
# {'subjects': [['0400c828-c2a7-5021-8bae-1aadf3206e21_1', 'No elections', 'concept'], ['0400c828-c2a7-5021-8bae-1aadf3206e21_2', 'No Crimea', 'concept'], ['0400c828-c2a7-5021-8bae-1aadf3206e21_3', 'No Donbass', 'concept'], ['0400c828-c2a7-5021-8bae-1aadf3206e21_4', 'No future', 'concept'], ['0400c828-c2a7-5021-8bae-1aadf3206e21_5', 'crests', 'concept'], ['0400c828-c2a7-5021-8bae-1aadf3206e21_6', 'Advertisement', 'object'], ['0400c828-c2a7-5021-8bae-1aadf3206e21_7', 'Wall', 'structure'], ['0400c828-c2a7-5021-8bae-1aadf3206e21_8', 'Graffiti', 'statement'], ['05afd37e-b223-544b-9eb1-6486f7adac34_1', 'Moscow', 'actor'], ['05afd37e-b223-544b-9eb1-6486f7adac34_2', 'Kiev regime', 'actor'], ['05afd37e-b223-544b-9eb1-6486f7adac34_3', 'Krasnopol', 'concept'], ['05afd37e-b223-544b-9eb1-6486f7adac34_4', 'Krasnodar region', 'location'], ['05afd37e-b223-544b-9eb1-6486f7adac34_5', 'doctors', 'actor'], ['05afd37e-b223-544b-9eb1-6486f7adac34_6', 'inadequate person', 'actor'], ['05afd37e-b223-544b-9eb1-6486f7adac34_7', 'Dagestan', 'location'], ['05afd37e-b223-544b-9eb1-6486f7adac34_8', 'Germany', 'location'], ['05afd37e-b223-544b-9eb1-6486f7adac34_9', 'Taurus', 'concept'], ['05afd37e-b223-544b-9eb1-6486f7adac34_10', 'Paris mayor', 'actor'], ['05afd37e-b223-544b-9eb1-6486f7adac34_11', 'Russian Foreign Ministry', 'actor'], ['05afd37e-b223-544b-9eb1-6486f7adac34_12', 'Soyuz-2.1b launch vehicle', 'concept'], ['05afd37e-b223-544b-9eb1-6486f7adac34_13', 'Macron', 'actor'], ['05afd37e-b223-544b-9eb1-6486f7adac34_14', 'Pakistan', 'location'], ['05afd37e-b223-544b-9eb1-6486f7adac34_15', 'Robbery', 'event'], ['05afd37e-b223-544b-9eb1-6486f7adac34_16', 'English', 'location'], ['05afd37e-b223-544b-9eb1-6486f7adac34_17', 'Telegram', 'concept'], ['05afd37e-b223-544b-9eb1-6486f7adac34_18', 'SOLOVIOV', 'actor'], ['05afd37e-b223-544b-9eb1-6486f7adac34_19', 'Telegram Channel', 'concept'], ['05afd37e-b223-544b-9eb1-6486f7adac34_20', 'Arrow Symbol', 'concept'], ['05afd37e-b223-544b-9eb1-6486f7adac34_21', 'Message', 'concept'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_1', 'Alexey KulemZin', 'actor'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_2', 'DPR JCCC', 'organization'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_3', 'Donetsk', 'location'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_4', 'Air Force', 'organization'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_5', 'Kirovsky district', 'location'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_6', 'Petrovsky district', 'location'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_7', 'Nazis', 'group'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_8', '155 mm caliber shells', 'object'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_9', 'VOP', 'object'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_10', 'UAV', 'object'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_11', 'Operational Report Graphic', 'object'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_12', 'Clipboard', 'object'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_13', 'Pen', 'object'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_14', 'Checklist', 'object'], ['08102ca6-f1c3-5590-8a22-c1c1d78870dc_15', 'Donetsk Operational Report Text', 'information']], 'relationships': [['0400c828-c2a7-5021-8bae-1aadf3206e21_8', 'is located on', '0400c828-c2a7-5021-8bae-1aadf3206e21_7', {'description': 'Graffiti on a building structure'}], ['0400c828-c2a7-5021-8bae-1aadf3206e21_6', 'adjacent to', '0400c828-c2a7-5021-8bae-1aadf3206e21_7', {'description': 'Advertisement next to a wall'}], ['05afd37e-b223-544b-9eb1-6486f7adac34_1', 'demands answer from', '05afd37e-b223-544b-9eb1-6486f7adac34_2', {'description': 'official communication'}], ['05afd37e-b223-544b-9eb1-6486f7adac34_3', 'used for', '05afd37e-b223-544b-9eb1-6486f7adac34_everywhere', {'description': 'tool application'}], ['05afd37e-b223-544b-9eb1-6486f7adac34_4', 'location of', '05afd37e-b223-544b-9eb1-6486f7adac34_6', {'description': 'incident location'}], ['05afd37e-b223-544b-9eb1-6486f7adac34_5', 'treated', '05afd37e-b223-544b-9eb1-6486f7adac34_6', {'description': 'medical treatment'}],  ...
# CPU times: user 86.2 ms, sys: 10.9 ms, total: 97.1 ms
# Wall time: 33.5 s

# %%
structured_data
# Out:
# {'subjects': [['5093e40c-1770-54dc-b4a3-c298b7d1ea72_1',
#    'Front-line laboratory',
#    'actor'],
#   ['5093e40c-1770-54dc-b4a3-c298b7d1ea72_2', 'UAV', 'concept'],
#   ['5093e40c-1770-54dc-b4a3-c298b7d1ea72_3', 'two majors', 'person'],
#   ['5093e40c-1770-54dc-b4a3-c298b7d1ea72_4', 'channel ZOV~ZOV26', 'event'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1', 'Roman Donetsky', 'person'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_2', 'Donbass front', 'location'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_3', 'Pervomaisky', 'location'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_4', 'Orlovka', 'location'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_5', 'Berdychi', 'location'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_6', 'Novomikhailovka', 'location'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_7', 'Georgievka', 'location'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_8', 'Avdeevka', 'location'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_9', 'UAVs', 'technology'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_10', 'PDF drones', 'technology'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_11', 'drone pilots', 'person'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_12', 'enemy', 'group'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_13', 'DPR', 'group'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_14', 'French-made KAB', 'weapon'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_15', 'Russian soldier', 'person'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_16', 'mankurt', 'person'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_17', 'reserves', 'concept'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_18', 'equipment', 'concept'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_19', 'morale', 'concept'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_20',
#    'tactic of a thousand cuts',
#    'strategy'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_21',
#    'video conferencing',
#    'technology'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_22', 'frontline', 'location'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_23', 'fortifications', 'concept'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_24', 'West', 'location'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_25', 'war', 'event'],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_26', 'victory', 'concept'],
#   ['06e6ddd6-9d30-5875-a0ca-fe4b4763da99_1', 'Zhytomyr', 'city'],
#   ['06e6ddd6-9d30-5875-a0ca-fe4b4763da99_2', 'Khmelnytskyi', 'city'],
#   ['06e6ddd6-9d30-5875-a0ca-fe4b4763da99_3', 'Poltava', 'city'],
#   ['06e6ddd6-9d30-5875-a0ca-fe4b4763da99_4', 'Kyiv', 'city'],
#   ['06e6ddd6-9d30-5875-a0ca-fe4b4763da99_5', 'ZSU', 'organization'],
#   ['dc13d1b8-bfba-5858-bc51-df94056ae3bb_1', 'St. Petersburg', 'location'],
#   ['dc13d1b8-bfba-5858-bc51-df94056ae3bb_2', 'transport', 'concept'],
#   ['dc13d1b8-bfba-5858-bc51-df94056ae3bb_3', 'tram', 'concept'],
#   ['e21054cd-c52e-5535-b1b1-0bc66c6d050c_1',
#    'Sergei Vladimirovich Ilyushin',
#    'Person'],
#   ['e21054cd-c52e-5535-b1b1-0bc66c6d050c_2', 'IL-2', 'Concept'],
#   ['e21054cd-c52e-5535-b1b1-0bc66c6d050c_3', 'T-34 Tank', 'Concept'],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_1', 'Vladimir Osechkin', 'person'],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_2', 'Mark Feigin', 'person'],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_3',
#    '22/03 terrorist attack',
#    'event'],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_4', 'Russia', 'actor'],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_5', 'world', 'actor'],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_6', 'Crocus Effect', 'concept'],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_7', 'Gulagu.net', 'actor'],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_8', 'Kiev', 'location'],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_9', 'YouTube', 'platform'],
#   ['d9a16294-6bbb-5652-a8d0-2241637d8b60_1', 'soldiers', 'actor'],
#   ['d9a16294-6bbb-5652-a8d0-2241637d8b60_2',
#    'American M2A2 Bradley ODS-SA infantry fighting vehicle',
#    'entity'],
#   ['d9a16294-6bbb-5652-a8d0-2241637d8b60_3',
#    'Avdeevsky direction',
#    'location'],
#   ['393635d4-4a01-5493-ab3f-30a69a355aa5_1', 'Ukraine', 'actor'],
#   ['393635d4-4a01-5493-ab3f-30a69a355aa5_2', 'EU', 'actor'],
#   ['393635d4-4a01-5493-ab3f-30a69a355aa5_3', 'The Telegraph', 'actor'],
#   ['393635d4-4a01-5493-ab3f-30a69a355aa5_4',
#    'extreme right-wing parties',
#    'actor'],
#   ['393635d4-4a01-5493-ab3f-30a69a355aa5_5', 'European Parliament', 'event'],
#   ['c27c3c15-6bdb-584b-9cfe-be73dff84328_1',
#    'captured M-777 howitzer',
#    'weapon'],
#   ['c27c3c15-6bdb-584b-9cfe-be73dff84328_2', 'Patriot Park', 'location'],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_1', 'S.V. Lavrov', 'person'],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_2', 'E. Macron', 'person'],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_3', 'Europe', 'actor'],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_4', 'China', 'actor'],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_5', 'V.A. Zelensky', 'person'],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_6', 'United States', 'actor'],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_7', 'Ukraine', 'actor'],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_8', 'Russia', 'actor'],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_9', 'Kazan', 'event'],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_10', 'BRICS', 'concept'],
#   ['148e925b-1a26-52a5-8941-bb97c4ba2b80_1', 'Great Britain', 'actor'],
#   ['148e925b-1a26-52a5-8941-bb97c4ba2b80_2', 'huskies', 'concept'],
#   ['148e925b-1a26-52a5-8941-bb97c4ba2b80_3',
#    'war with Russia in the Arctic',
#    'event'],
#   ['148e925b-1a26-52a5-8941-bb97c4ba2b80_4', 'military', 'actor'],
#   ['148e925b-1a26-52a5-8941-bb97c4ba2b80_5',
#    'ammunition and food supply',
#    'concept'],
#   ['148e925b-1a26-52a5-8941-bb97c4ba2b80_6',
#    'raids on enemy territory',
#    'event'],
#   ['148e925b-1a26-52a5-8941-bb97c4ba2b80_7', 'Daily Mail', 'actor'],
#   ['d1b7cfcc-cb8c-5273-b09a-fa6976347108_1', 'Biden', 'person'],
#   ['d1b7cfcc-cb8c-5273-b09a-fa6976347108_2', 'Trump', 'person'],
#   ['d1b7cfcc-cb8c-5273-b09a-fa6976347108_3', 'golf', 'activity'],
#   ['d1b7cfcc-cb8c-5273-b09a-fa6976347108_4', 'clubs', 'object'],
#   ['0871898f-24fe-5dd0-af57-b5ad8b9c1c26_1', 'alter ego', 'actor'],
#   ['0871898f-24fe-5dd0-af57-b5ad8b9c1c26_2',
#    'Ukraine-Russia Conflict',
#    'concept'],
#   ['844714f3-caa4-5c61-b746-6fda9d09828b_1', 'A50', 'aircraft'],
#   ['844714f3-caa4-5c61-b746-6fda9d09828b_2', 'Nautilus', 'concept'],
#   ['844714f3-caa4-5c61-b746-6fda9d09828b_3', 'Captain Nemo', 'person'],
#   ['844714f3-caa4-5c61-b746-6fda9d09828b_4', 'Russians', 'actor'],
#   ['844714f3-caa4-5c61-b746-6fda9d09828b_5', 'Moscow cruiser', 'concept'],
#   ['844714f3-caa4-5c61-b746-6fda9d09828b_6', 'submarine', 'concept'],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_1', 'Insider UAPhoto', 'actor'],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_2', 'Russian glide bombs', 'concept'],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_3', 'war in Ukraine', 'event'],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_4', 'The Times', 'actor'],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_5', 'Kharkov', 'location'],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_6', 'KABs', 'concept'],
#   ['fb5a8611-40fb-502b-acf3-0fb5e3c07a44_1',
#    'Ukrainian shelling of Yasinovataya',
#    'event'],
#   ['fb5a8611-40fb-502b-acf3-0fb5e3c07a44_2', 'apartment buildings', 'concept'],
#   ['fb5a8611-40fb-502b-acf3-0fb5e3c07a44_3', 'eyewitnesses', 'actor'],
#   ['fb5a8611-40fb-502b-acf3-0fb5e3c07a44_4', 'RIA Novosti', 'actor'],
#   ['bdea7d33-46f5-51fc-95ad-0be9911092f3_1',
#    'Mayor of Kharkiv Terekhov',
#    'person'],
#   ['bdea7d33-46f5-51fc-95ad-0be9911092f3_2', 'Russian Federation', 'actor'],
#   ['bdea7d33-46f5-51fc-95ad-0be9911092f3_3',
#    'Residential building in Kharkiv',
#    'location'],
#   ['bdea7d33-46f5-51fc-95ad-0be9911092f3_4',
#    'Central area of Kharkiv',
#    'location'],
#   ['bdea7d33-46f5-51fc-95ad-0be9911092f3_5', 'Fokus', 'media outlet'],
#   ['bdea7d33-46f5-51fc-95ad-0be9911092f3_6',
#    'YouTube channel Fokus',
#    'media outlet'],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_1', 'Moscow', 'actor'],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_2', 'Kyiv', 'actor'],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_3', 'Minsk', 'actor'],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_4', 'RIA Novosti', 'actor'],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_5',
#    'TelegramV Z - VZGLYAD.RUMID',
#    'actor'],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_6',
#    'Russian Foreign Ministry',
#    'actor'],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_7', 'Ukrainian authorities', 'actor'],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_8', 'terrorist attacks', 'event'],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_1', 'Putin', 'person'],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_2', 'SBU', 'actor'],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_3', 'The Hague Tribunal', 'event'],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_4', 'Russian Federation', 'actor'],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_5',
#    'Ministry of Foreign Affairs of Russia',
#    'actor'],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_6', 'Vladimir Putin', 'person'],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_7', 'OBOZ.UA', 'actor'],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_8',
#    'Convention on Combating Terrorism',
#    'concept'],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_9', 'International law', 'concept'],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_10',
#    'The Russian president',
#    'person'],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_11',
#    ' kidnapping Ukrainian children',
#    'concept'],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_1', 'KORNILOV', 'person'],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_2',
#    'USSR Ministry of Foreign Affairs',
#    'actor'],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_3', 'NATO', 'event'],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_4', 'Europe', 'concept'],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_5', 'issue proposal', 'concept'],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_6',
#    'confrontation prevention',
#    'concept'],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_7', 'military blocs', 'concept'],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_8', 'West', 'concept'],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_9', 'aggressive nature', 'concept'],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_10', 'Russia', 'concept'],
#   ['aea155a0-9aa3-586d-b42a-7b9a86f42a78_1', 'Ukrainians', 'actor'],
#   ['aea155a0-9aa3-586d-b42a-7b9a86f42a78_2', 'European Union', 'actor'],
#   ['aea155a0-9aa3-586d-b42a-7b9a86f42a78_3', 'NATO', 'actor'],
#   ['aea155a0-9aa3-586d-b42a-7b9a86f42a78_4', 'USA', 'actor'],
#   ['aea155a0-9aa3-586d-b42a-7b9a86f42a78_5', 'VoxCheck analysts', 'actor'],
#   ['aea155a0-9aa3-586d-b42a-7b9a86f42a78_6', 'propagandists', 'actor'],
#   ['aea155a0-9aa3-586d-b42a-7b9a86f42a78_7', 'Frame Order', 'actor'],
#   ['270aed57-afdf-5fa3-a6da-dc24d7448470_1',
#    'militants of Ukrainian formations',
#    'actor'],
#   ['270aed57-afdf-5fa3-a6da-dc24d7448470_2', 'Russian Armed Forces', 'actor'],
#   ['19f7b22e-bbc8-5536-b2fd-49035b599ea4_1', 'LOSTARMOUR', 'actor'],
#   ['19f7b22e-bbc8-5536-b2fd-49035b599ea4_2', 'n.p. Vodyanoye', 'location'],
#   ['19f7b22e-bbc8-5536-b2fd-49035b599ea4_3', 'Donetsk', 'location'],
#   ['f588c8d4-ae74-5ffa-9657-c0c241263b8e_1', 'Russian', 'actor'],
#   ['f588c8d4-ae74-5ffa-9657-c0c241263b8e_2', 'trees', 'concept'],
#   ['f588c8d4-ae74-5ffa-9657-c0c241263b8e_3', 'night', 'concept'],
#   ['f588c8d4-ae74-5ffa-9657-c0c241263b8e_4', 'drones', 'actor'],
#   ['2d0b957e-6b98-55a4-8971-d4b4679b1c87_1', 'Ukraine', 'actor'],
#   ['2d0b957e-6b98-55a4-8971-d4b4679b1c87_2', 'Russia', 'actor'],
#   ['2d0b957e-6b98-55a4-8971-d4b4679b1c87_3', 'Ceasefire Agreement', 'event'],
#   ['2d0b957e-6b98-55a4-8971-d4b4679b1c87_4', 'Conflict Resolution', 'concept'],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_1', 'Russia', 'actor'],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_2', 'Ukraine', 'actor'],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_3',
#    'Crocus terrorist attack',
#    'event'],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_4',
#    'Russian Foreign Ministry',
#    'actor'],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_5', 'SBU Malyuk', 'actor'],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_6',
#    'Crimean Bridge bombing',
#    'event'],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_7',
#    'Murder in the Russian Federation',
#    'event'],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_8', 'Tatarsky', 'location'],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_1', 'Military Personnel', 'Actor'],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_2',
#    'Families of Military Personnel',
#    'Actor'],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_3', 'Teleconference', 'Event'],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_4',
#    'Northern Military District',
#    'Location'],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_5', 'Sakhalin', 'Location'],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_6',
#    "Donetsk People's Republic",
#    'Location'],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_7', 'Video Communication', 'Concept'],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_8', 'Dolinsk', 'Location'],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_9', 'Kholmsk', 'Location'],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_10', 'Makarov', 'Location'],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_11', 'Fighters', 'Actor'],
#   ['4985d0da-256e-5172-8c5f-0ec156d0a94e_1', 'SurSever', 'actor'],
#   ['4985d0da-256e-5172-8c5f-0ec156d0a94e_2',
#    'Results of the week in Luhansk Region 25.03-31.03.2024',
#    'event'],
#   ['4985d0da-256e-5172-8c5f-0ec156d0a94e_3', 'Luhansk Region', 'location'],
#   ['96d90f49-ec47-56af-9e51-c7b840f54eff_1',
#    'Artillerymen of the 58th Army',
#    'actor'],
#   ['96d90f49-ec47-56af-9e51-c7b840f54eff_2',
#    'Armored vehicles of Ukrainian Armed Forces militants',
#    'actor'],
#   ['96d90f49-ec47-56af-9e51-c7b840f54eff_3', 'Rabotino area', 'location'],
#   ['96d90f49-ec47-56af-9e51-c7b840f54eff_4',
#    'Zaporozhye direction',
#    'location'],
#   ['96d90f49-ec47-56af-9e51-c7b840f54eff_5',
#    'Krasnopol adjustable artillery ammunition',
#    'concept'],
#   ['2acaf432-a7ee-5ac5-9ed9-27907cacaea1_1', 'Kherson', 'location'],
#   ['2acaf432-a7ee-5ac5-9ed9-27907cacaea1_2', 'Red zone', 'concept'],
#   ['2acaf432-a7ee-5ac5-9ed9-27907cacaea1_3', 'Fortifications', 'concept'],
#   ['2acaf432-a7ee-5ac5-9ed9-27907cacaea1_4', 'Mines', 'concept'],
#   ['2acaf432-a7ee-5ac5-9ed9-27907cacaea1_5', 'Frigate area', 'location'],
#   ['2acaf432-a7ee-5ac5-9ed9-27907cacaea1_6',
#    'Karl Marx Street (Potemkinskaya)',
#    'location'],
#   ['c9e2da87-1c2d-58fe-ad48-3033050276bd_1',
#    'Soldiers of the 80th ODSHBr',
#    'actor'],
#   ['c9e2da87-1c2d-58fe-ad48-3033050276bd_2', 'enemy tank', 'actor'],
#   ['c9e2da87-1c2d-58fe-ad48-3033050276bd_3', 'three BMPs', 'actor'],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_1', 'DiyTy', 'actor'],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_2', 'Victoria Rohachova', 'person'],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_3',
#    'American 155 mm Projectile Tube Painting',
#    'artifact'],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_4', 'Cotton Flowers', 'concept'],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_5',
#    'Armed Forces of Ukraine',
#    'group'],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_6',
#    'PNB (Personal Protective Equipment)',
#    'concept'],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_7', 'Kherson Region', 'location'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_1', 'Sergei Shoigu', 'Person'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_2', 'President', 'Person'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_3',
#    'Defense Complex Enterprise in Altai',
#    'Organization'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_4', 'Minister of Defense', 'Person'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_5', 'Workers', 'Group'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_6', 'Production Sites', 'Location'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_7', 'Examination Delay', 'Concept'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_8', 'Bureaucrats', 'Group'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_9', 'Second World War', 'Event'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_10', 'Nannies', 'Group'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_11',
#    'Child without an eye',
#    'Concept'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_12',
#    'Defense Industry Enterprises',
#    'Organization'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_13', 'Rostec', 'Organization'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_14', 'Director', 'Person'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_15',
#    'Calibers of Ammunition',
#    'Concept'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_16', 'Factory Owners', 'Group'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_17', 'Shareholders', 'Group'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_18', 'Sabotage', 'Concept'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_19', 'Foreign Influence', 'Concept'],
#   ['683fcdec-a977-5367-8583-1828acabc83a_20',
#    'Temporary Management Institute',
#    'Organization'],
#   ['dae4b91a-789d-51ac-ba7f-63e9ab4e78e8_1', 'Rostov', 'Location'],
#   ['dae4b91a-789d-51ac-ba7f-63e9ab4e78e8_2', 'Explosion', 'Event'],
#   ['14a4c38b-558f-5658-a87f-bd0d5b4acdcb_1', 'Xiaomi', 'actor'],
#   ['14a4c38b-558f-5658-a87f-bd0d5b4acdcb_2', 'Donetsk', 'location'],
#   ['14a4c38b-558f-5658-a87f-bd0d5b4acdcb_3', 'Makeevka', 'location'],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_1', 'Kirill Fedorov', 'actor'],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_2',
#    'Tank Platoon Commander',
#    'actor'],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_3', 'T-72B3M 2023', 'entity'],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_4', 'Tank', 'concept'],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_5', 'Russia', 'actor'],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_6', 'Ukraine', 'actor'],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_7',
#    'Electronic Warfare System',
#    'concept'],
#   ['4636768e-14e6-5844-98e0-211e7a450519_1', 'Israeli Air Force', 'actor'],
#   ['4636768e-14e6-5844-98e0-211e7a450519_2', 'Damascus', 'location'],
#   ['4636768e-14e6-5844-98e0-211e7a450519_3', 'Syria', 'location'],
#   ['4636768e-14e6-5844-98e0-211e7a450519_4',
#    'new_militarycolumnist',
#    'person'],
#   ['f381cb04-0776-5651-b432-9d88cd65a3e6_1', 'Ukrainians', 'actor'],
#   ['f381cb04-0776-5651-b432-9d88cd65a3e6_2', 'homemade ammunition', 'concept'],
#   ['f381cb04-0776-5651-b432-9d88cd65a3e6_3', 'Baba Yaga drone', 'concept'],
#   ['f381cb04-0776-5651-b432-9d88cd65a3e6_4', '@NeoficialniyBeZsonoV', 'actor'],
#   ['16aeba2a-8489-5d3e-bfde-b65a8c898ccd_1', 'Israeli Government', 'Actor'],
#   ['16aeba2a-8489-5d3e-bfde-b65a8c898ccd_2', 'Gaza Strip', 'Location'],
#   ['16aeba2a-8489-5d3e-bfde-b65a8c898ccd_3', 'Rafah', 'Location'],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_1', 'Protesters', 'Actor'],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_2', 'Tel Aviv', 'Location'],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_3', 'Israeli cities', 'Location'],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_4',
#    'Prime Minister Netanyahu',
#    'Person'],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_5', 'Hostages', 'Concept'],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_6', 'Video', 'Event'],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_7', 'Israelis', 'Actor'],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_8', 'Knesset building', 'Location'],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_9', 'Jerusalem', 'Location'],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_10', 'Government', 'Concept'],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_11', 'Telegram SOLOVIOV', 'Concept'],
#   ['1aa793cd-f09d-5a4e-8946-5b7b60e71f42_1', 'Israelis', 'actor'],
#   ['1aa793cd-f09d-5a4e-8946-5b7b60e71f42_2', 'Tel Aviv protests', 'event'],
#   ['1aa793cd-f09d-5a4e-8946-5b7b60e71f42_3', 'hostages', 'concept'],
#   ['1aa793cd-f09d-5a4e-8946-5b7b60e71f42_4', 'Gaza Strip', 'concept'],
#   ['1aa793cd-f09d-5a4e-8946-5b7b60e71f42_5', 'Bild', 'actor'],
#   ['3ed53e18-1d60-5384-8cc6-eb29ad04a92d_1', 'Ekrem Imamoglu', 'person'],
#   ['3ed53e18-1d60-5384-8cc6-eb29ad04a92d_2', 'Mansur Yavas', 'person'],
#   ['3ed53e18-1d60-5384-8cc6-eb29ad04a92d_3', 'Cemil Tugay', 'person'],
#   ['3ed53e18-1d60-5384-8cc6-eb29ad04a92d_4', 'Istanbul', 'location'],
#   ['3ed53e18-1d60-5384-8cc6-eb29ad04a92d_5', 'Ankara', 'location'],
#   ['3ed53e18-1d60-5384-8cc6-eb29ad04a92d_6', 'Izmir', 'location'],
#   ['a6ef3fa5-f1f3-59e0-b0b0-8940bc75aab5_1', 'Kargach🇷🇺⚡️Ꙃ', 'actor'],
#   ['a6ef3fa5-f1f3-59e0-b0b0-8940bc75aab5_2', 'Teletubbies', 'concept'],
#   ['a6ef3fa5-f1f3-59e0-b0b0-8940bc75aab5_3', 'Donations', 'concept']],
#  'relationships': [['5093e40c-1770-54dc-b4a3-c298b7d1ea72_1',
#    'provides repair services for',
#    '5093e40c-1770-54dc-b4a3-c298b7d1ea72_2',
#    {'label': 'service'}],
#   ['5093e40c-1770-54dc-b4a3-c298b7d1ea72_1',
#    'employs',
#    '5093e40c-1770-54dc-b4a3-c298b7d1ea72_3',
#    {'role': 'major'}],
#   ['5093e40c-1770-54dc-b4a3-c298b7d1ea72_1',
#    'broadcasts updates on',
#    '5093e40c-1770-54dc-b4a3-c298b7d1ea72_4',
#    {'channel': 'ZOV~ZOV26'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'reports from',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_2',
#    {'context': 'military conflict'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'controls',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_3',
#    {'status': 'partially'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'mentions battles in',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_4',
#    {'status': 'ongoing'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'mentions tough battles in',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_5',
#    {'status': 'ongoing'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'mentions battle for',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_6',
#    {'status': 'ongoing'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'mentions battle for',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_7',
#    {'status': 'ongoing'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'reports on situation in',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_8',
#    {'status': 'pinned down'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'highlights problem with',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_9',
#    {'threat': 'rear attacks'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'refers to',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_10',
#    {'usage': 'saturated drones in positional phase'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'acknowledges challenges faced by',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_11',
#    {'role': 'creating problems for enemy'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'mentions actions of',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_12',
#    {'activity': 'bringing reserves and UAVs into battle'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'mentions attacks on',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_13',
#    {'casualties': '74 shells fired at civilian buildings'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'emphasizes importance of',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_14',
#    {'usage': 'by enemy'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'acknowledges presence of',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_15',
#    {'description': 'Russian soldiers in conflict'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'mentions the presence of',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_16',
#    {'description': 'Russian, but from a totalitarian state'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'points out impact of',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_20',
#    {'effect': 'tactical strategy'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'mentions activation of',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_21',
#    {'impact': 'facilitating communication'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'discusses',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_23',
#    {'feature': 'freezing of the front'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    "warns of potential 'surprises' from",
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_24',
#    {'direction': 'West'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'reflects on ongoing',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_25',
#    {'status': 'continuation of conflict'}],
#   ['9dcd79d7-e512-5f3e-8d0b-07f522ffa771_1',
#    'praises',
#    '9dcd79d7-e512-5f3e-8d0b-07f522ffa771_26',
#    {'description': "Russian soldier's perseverance"}],
#   ['06e6ddd6-9d30-5875-a0ca-fe4b4763da99_1',
#    'allocated budget for defense in',
#    '06e6ddd6-9d30-5875-a0ca-fe4b4763da99_5',
#    {'percentage': '38% in 2023'}],
#   ['06e6ddd6-9d30-5875-a0ca-fe4b4763da99_2',
#    'received help from',
#    '06e6ddd6-9d30-5875-a0ca-fe4b4763da99_5',
#    {'organization': 'ZSU'}],
#   ['06e6ddd6-9d30-5875-a0ca-fe4b4763da99_3',
#    'received help from',
#    '06e6ddd6-9d30-5875-a0ca-fe4b4763da99_5',
#    {'organization': 'ZSU'}],
#   ['06e6ddd6-9d30-5875-a0ca-fe4b4763da99_4',
#    'received help from',
#    '06e6ddd6-9d30-5875-a0ca-fe4b4763da99_5',
#    {'organization': 'ZSU'}],
#   ['e21054cd-c52e-5535-b1b1-0bc66c6d050c_1',
#    'created',
#    'e21054cd-c52e-5535-b1b1-0bc66c6d050c_2',
#    {'description': 'Constructor of the IL-2 aircraft'}],
#   ['e21054cd-c52e-5535-b1b1-0bc66c6d050c_1',
#    'known for',
#    'e21054cd-c52e-5535-b1b1-0bc66c6d050c_2',
#    {'description': 'Legendary aircraft designer'}],
#   ['e21054cd-c52e-5535-b1b1-0bc66c6d050c_2',
#    'related to',
#    'e21054cd-c52e-5535-b1b1-0bc66c6d050c_3',
#    {'description': 'Comparison made in the post'}],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_1',
#    'participating in',
#    'ce74d48e-be27-5096-8c57-f89a6a724ccf_3',
#    {'role': 'discussion'}],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_2',
#    'participating in',
#    'ce74d48e-be27-5096-8c57-f89a6a724ccf_3',
#    {'role': 'discussion'}],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_3',
#    'related to',
#    'ce74d48e-be27-5096-8c57-f89a6a724ccf_4',
#    {'type': 'consequences'}],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_3',
#    'related to',
#    'ce74d48e-be27-5096-8c57-f89a6a724ccf_5',
#    {'type': 'consequences'}],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_6',
#    'related to',
#    'ce74d48e-be27-5096-8c57-f89a6a724ccf_3',
#    {'type': 'topic'}],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_7',
#    'mentioned in',
#    'ce74d48e-be27-5096-8c57-f89a6a724ccf_1',
#    {'role': 'founder'}],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_7',
#    'mentioned in',
#    'ce74d48e-be27-5096-8c57-f89a6a724ccf_2',
#    {'role': 'human rights activist'}],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_8',
#    'includes',
#    'ce74d48e-be27-5096-8c57-f89a6a724ccf_3',
#    {}],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_9',
#    'provides platform for',
#    'ce74d48e-be27-5096-8c57-f89a6a724ccf_1',
#    {}],
#   ['ce74d48e-be27-5096-8c57-f89a6a724ccf_9',
#    'provides platform for',
#    'ce74d48e-be27-5096-8c57-f89a6a724ccf_2',
#    {}],
#   ['d9a16294-6bbb-5652-a8d0-2241637d8b60_1',
#    'captured',
#    'd9a16294-6bbb-5652-a8d0-2241637d8b60_2',
#    {'detail': 'third captured'}],
#   ['d9a16294-6bbb-5652-a8d0-2241637d8b60_3',
#    'related to',
#    'd9a16294-6bbb-5652-a8d0-2241637d8b60_2',
#    {}],
#   ['393635d4-4a01-5493-ab3f-30a69a355aa5_1',
#    'faces threat from',
#    '393635d4-4a01-5493-ab3f-30a69a355aa5_3',
#    {'source': 'The Telegraph'}],
#   ['393635d4-4a01-5493-ab3f-30a69a355aa5_1',
#    'wants to accede to',
#    '393635d4-4a01-5493-ab3f-30a69a355aa5_2',
#    {'source': 'The Telegraph'}],
#   ['393635d4-4a01-5493-ab3f-30a69a355aa5_2',
#    'decides to support',
#    '393635d4-4a01-5493-ab3f-30a69a355aa5_1',
#    {'source': 'The Telegraph'}],
#   ['393635d4-4a01-5493-ab3f-30a69a355aa5_4',
#    'opposes support for',
#    '393635d4-4a01-5493-ab3f-30a69a355aa5_1',
#    {'source': 'The Telegraph'}],
#   ['393635d4-4a01-5493-ab3f-30a69a355aa5_4',
#    'can veto decisions of',
#    '393635d4-4a01-5493-ab3f-30a69a355aa5_2',
#    {'source': 'The Telegraph'}],
#   ['393635d4-4a01-5493-ab3f-30a69a355aa5_4',
#    'might win elections to',
#    '393635d4-4a01-5493-ab3f-30a69a355aa5_5',
#    {'source': 'The Telegraph'}],
#   ['393635d4-4a01-5493-ab3f-30a69a355aa5_5',
#    'affects',
#    '393635d4-4a01-5493-ab3f-30a69a355aa5_1',
#    {'source': 'The Telegraph'}],
#   ['c27c3c15-6bdb-584b-9cfe-be73dff84328_1',
#    'located in',
#    'c27c3c15-6bdb-584b-9cfe-be73dff84328_2',
#    {}],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_1',
#    'gave interview to',
#    '8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_0',
#    {'location': 'Izvestia Research Center, Moscow', 'date': 'March 28, 2024'}],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_1',
#    'mentioned',
#    '8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_2',
#    {'relatedIdea': 'performance repeated'}],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_1',
#    'commented on',
#    '8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_3',
#    {'comment': 'lack of logic and focus in actions'}],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_4',
#    'published',
#    '8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_0',
#    {'document': '12-point plan to resolve conflict in Ukraine'}],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_4',
#    'responded positively to',
#    '8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_0',
#    {'document': 'Chinese plan'}],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_6',
#    'aiding',
#    '8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_7',
#    {'support': 'providing modern long-range weapons'}],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_6',
#    'mentioned',
#    '8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_7',
#    {'strategy': 'letting Ukraine and Russia shoot at each other'}],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_1',
#    'mentioned',
#    '8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_9',
#    {'summit': 'fall summit in Kazan'}],
#   ['8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_1',
#    'mentioned',
#    '8e7cdd58-eccf-5ee5-acc1-7dd2937fd6eb_10',
#    {'summit': 'introducing new category of partner country'}],
#   ['148e925b-1a26-52a5-8941-bb97c4ba2b80_1',
#    'trains',
#    '148e925b-1a26-52a5-8941-bb97c4ba2b80_2',
#    {'purpose': 'preparing for war'}],
#   ['148e925b-1a26-52a5-8941-bb97c4ba2b80_2',
#    'possible role in',
#    '148e925b-1a26-52a5-8941-bb97c4ba2b80_3',
#    {}],
#   ['148e925b-1a26-52a5-8941-bb97c4ba2b80_4',
#    'expects assistance from',
#    '148e925b-1a26-52a5-8941-bb97c4ba2b80_2',
#    {'supplies': ['ammunition', 'food']}],
#   ['148e925b-1a26-52a5-8941-bb97c4ba2b80_4',
#    'conducts',
#    '148e925b-1a26-52a5-8941-bb97c4ba2b80_6',
#    {'purpose': 'raids'}],
#   ['148e925b-1a26-52a5-8941-bb97c4ba2b80_7',
#    'reports in',
#    '148e925b-1a26-52a5-8941-bb97c4ba2b80_4',
#    {}],
#   ['d1b7cfcc-cb8c-5273-b09a-fa6976347108_1',
#    'invited to',
#    'd1b7cfcc-cb8c-5273-b09a-fa6976347108_2',
#    {'promise': 'play golf'}],
#   ['d1b7cfcc-cb8c-5273-b09a-fa6976347108_1',
#    'offered',
#    'd1b7cfcc-cb8c-5273-b09a-fa6976347108_2',
#    {'promise': 'three-stroke head start'}],
#   ['d1b7cfcc-cb8c-5273-b09a-fa6976347108_1',
#    'offered',
#    'd1b7cfcc-cb8c-5273-b09a-fa6976347108_2',
#    {'promise': 'carry his own bag of clubs'}],
#   ['d1b7cfcc-cb8c-5273-b09a-fa6976347108_3',
#    'involves',
#    'd1b7cfcc-cb8c-5273-b09a-fa6976347108_1',
#    {'action': 'play'}],
#   ['d1b7cfcc-cb8c-5273-b09a-fa6976347108_3',
#    'involves',
#    'd1b7cfcc-cb8c-5273-b09a-fa6976347108_2',
#    {'action': 'play'}],
#   ['d1b7cfcc-cb8c-5273-b09a-fa6976347108_4',
#    'related to',
#    'd1b7cfcc-cb8c-5273-b09a-fa6976347108_3',
#    {'used for': 'playing'}],
#   ['844714f3-caa4-5c61-b746-6fda9d09828b_1',
#    'related to',
#    '844714f3-caa4-5c61-b746-6fda9d09828b_2',
#    {}],
#   ['844714f3-caa4-5c61-b746-6fda9d09828b_3',
#    'mentioned in relation with',
#    '844714f3-caa4-5c61-b746-6fda9d09828b_4',
#    {}],
#   ['844714f3-caa4-5c61-b746-6fda9d09828b_5',
#    'related to',
#    '844714f3-caa4-5c61-b746-6fda9d09828b_1',
#    {}],
#   ['844714f3-caa4-5c61-b746-6fda9d09828b_6',
#    'related to',
#    '844714f3-caa4-5c61-b746-6fda9d09828b_1',
#    {}],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_1',
#    'published article about',
#    '4059dacd-25d1-50ad-b4a6-b43e8dca224d_3',
#    {'location': 'Kharkov'}],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_1',
#    'published article about',
#    '4059dacd-25d1-50ad-b4a6-b43e8dca224d_2',
#    {'impact': 'changing the course of the war'}],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_4',
#    'published article about',
#    '4059dacd-25d1-50ad-b4a6-b43e8dca224d_3',
#    {'location': 'Kharkov'}],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_4',
#    'published article about',
#    '4059dacd-25d1-50ad-b4a6-b43e8dca224d_2',
#    {'impact': 'changing the course of the war'}],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_3',
#    'involved in',
#    '4059dacd-25d1-50ad-b4a6-b43e8dca224d_2',
#    {}],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_5',
#    'is location of',
#    '4059dacd-25d1-50ad-b4a6-b43e8dca224d_3',
#    {}],
#   ['4059dacd-25d1-50ad-b4a6-b43e8dca224d_6',
#    'mentioned in',
#    '4059dacd-25d1-50ad-b4a6-b43e8dca224d_1',
#    {}],
#   ['fb5a8611-40fb-502b-acf3-0fb5e3c07a44_1',
#    'involved',
#    'fb5a8611-40fb-502b-acf3-0fb5e3c07a44_2',
#    {'location': 'Yasinovataya'}],
#   ['fb5a8611-40fb-502b-acf3-0fb5e3c07a44_1',
#    'reported by',
#    'fb5a8611-40fb-502b-acf3-0fb5e3c07a44_3',
#    {}],
#   ['fb5a8611-40fb-502b-acf3-0fb5e3c07a44_1',
#    'reported by',
#    'fb5a8611-40fb-502b-acf3-0fb5e3c07a44_4',
#    {}],
#   ['fb5a8611-40fb-502b-acf3-0fb5e3c07a44_2',
#    'affected by',
#    'fb5a8611-40fb-502b-acf3-0fb5e3c07a44_1',
#    {'damage': 'facade'}],
#   ['bdea7d33-46f5-51fc-95ad-0be9911092f3_1',
#    'reported incident involving',
#    'bdea7d33-46f5-51fc-95ad-0be9911092f3_2',
#    {'property': 'stated'}],
#   ['bdea7d33-46f5-51fc-95ad-0be9911092f3_2',
#    'struck near',
#    'bdea7d33-46f5-51fc-95ad-0be9911092f3_3',
#    {'property': 'location'}],
#   ['bdea7d33-46f5-51fc-95ad-0be9911092f3_2',
#    'struck near',
#    'bdea7d33-46f5-51fc-95ad-0be9911092f3_4',
#    {'property': 'location'}],
#   ['bdea7d33-46f5-51fc-95ad-0be9911092f3_5',
#    'received news from',
#    'bdea7d33-46f5-51fc-95ad-0be9911092f3_1',
#    {'property': 'source'}],
#   ['bdea7d33-46f5-51fc-95ad-0be9911092f3_5',
#    'featured in',
#    'bdea7d33-46f5-51fc-95ad-0be9911092f3_6',
#    {'property': 'mentioned'}],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_1',
#    'sent message to',
#    '4a2a7a8b-1c0a-5c62-a609-153deb83060b_2',
#    {'channel': 'established channel through Minsk'}],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_4',
#    'reported by',
#    '4a2a7a8b-1c0a-5c62-a609-153deb83060b_6',
#    {'reference': 'Foreign Ministry'}],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_5',
#    'handed over demands to',
#    '4a2a7a8b-1c0a-5c62-a609-153deb83060b_7',
#    {'demand': 'immediate arrest and extradition'}],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_8',
#    'related to',
#    '4a2a7a8b-1c0a-5c62-a609-153deb83060b_1',
#    {}],
#   ['4a2a7a8b-1c0a-5c62-a609-153deb83060b_8',
#    'related to',
#    '4a2a7a8b-1c0a-5c62-a609-153deb83060b_5',
#    {}],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_2',
#    'put Russians on the spot',
#    '5285287c-3372-5e34-a3f5-65739fa845d9_4',
#    {'location': 'Ukraine'}],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_2',
#    'reminded',
#    '5285287c-3372-5e34-a3f5-65739fa845d9_4',
#    {'statement': 'cynical statements about terrorism'}],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_2',
#    'reported by',
#    '5285287c-3372-5e34-a3f5-65739fa845d9_7',
#    {'comment': 'exclusive'}],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_2',
#    'waiting for',
#    '5285287c-3372-5e34-a3f5-65739fa845d9_1',
#    {'location': 'The Hague'}],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_2',
#    'awaited at',
#    '5285287c-3372-5e34-a3f5-65739fa845d9_3',
#    {'reason': 'kidnapping Ukrainian children'}],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_4',
#    'makes statements about',
#    '5285287c-3372-5e34-a3f5-65739fa845d9_8',
#    {'type': 'terrorism'}],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_4',
#    'forgetting',
#    '5285287c-3372-5e34-a3f5-65739fa845d9_9',
#    {'fact': 'Putin is an international wanted man'}],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_4',
#    'belongs to',
#    '5285287c-3372-5e34-a3f5-65739fa845d9_10',
#    {'location': 'Russia'}],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_5',
#    'attempts to appeal to',
#    '5285287c-3372-5e34-a3f5-65739fa845d9_9',
#    {'norms': 'international law'}],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_5',
#    'forgets',
#    '5285287c-3372-5e34-a3f5-65739fa845d9_9',
#    {'fact': 'Putin declared international wanted man'}],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_6',
#    'waiting for',
#    '5285287c-3372-5e34-a3f5-65739fa845d9_3',
#    {'reason': 'kidnapping Ukrainian children'}],
#   ['5285287c-3372-5e34-a3f5-65739fa845d9_2',
#    'emphasized',
#    '5285287c-3372-5e34-a3f5-65739fa845d9_5',
#    {'content': 'Vladimir Putin being an international wanted man'}],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_1',
#    'forwarded message from',
#    '13c726c9-bfb5-5c93-9cab-2af3c5691409_1',
#    {'property': 'message forwarding'}],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_2',
#    'proposed issue to',
#    '13c726c9-bfb5-5c93-9cab-2af3c5691409_3',
#    {'property': 'diplomatic proposal'}],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_2',
#    'proposed issue to',
#    '13c726c9-bfb5-5c93-9cab-2af3c5691409_5',
#    {'property': 'diplomatic proposal'}],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_2',
#    'proposed issue to',
#    '13c726c9-bfb5-5c93-9cab-2af3c5691409_6',
#    {'property': 'diplomatic proposal'}],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_2',
#    'proposed issue to',
#    '13c726c9-bfb5-5c93-9cab-2af3c5691409_7',
#    {'property': 'diplomatic proposal'}],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_3',
#    'admission proposal by',
#    '13c726c9-bfb5-5c93-9cab-2af3c5691409_10',
#    {'property': 'rejected admission proposal'}],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_3',
#    'admission proposal by',
#    '13c726c9-bfb5-5c93-9cab-2af3c5691409_9',
#    {'property': 'rejected admission proposal'}],
#   ['13c726c9-bfb5-5c93-9cab-2af3c5691409_8',
#    'rejected proposal from',
#    '13c726c9-bfb5-5c93-9cab-2af3c5691409_2',
#    {'property': 'rejected proposal'}],
#   ['aea155a0-9aa3-586d-b42a-7b9a86f42a78_1',
#    'featured in',
#    'aea155a0-9aa3-586d-b42a-7b9a86f42a78_6',
#    {'label': 'fake news'}],
#   ['aea155a0-9aa3-586d-b42a-7b9a86f42a78_6',
#    'created',
#    'aea155a0-9aa3-586d-b42a-7b9a86f42a78_7',
#    {'label': 'animation creator'}],
#   ['270aed57-afdf-5fa3-a6da-dc24d7448470_1',
#    'experiences',
#    '270aed57-afdf-5fa3-a6da-dc24d7448470_2',
#    {'condition': 'constant fire'}],
#   ['19f7b22e-bbc8-5536-b2fd-49035b599ea4_1',
#    'operated in',
#    '19f7b22e-bbc8-5536-b2fd-49035b599ea4_3',
#    {'description': 'Released in the Donetsk direction'}],
#   ['19f7b22e-bbc8-5536-b2fd-49035b599ea4_2',
#    'located at',
#    '19f7b22e-bbc8-5536-b2fd-49035b599ea4_3',
#    {'description': 'Coordinates: 48.1049533, 37.5906768'}],
#   ['f588c8d4-ae74-5ffa-9657-c0c241263b8e_1',
#    'hid among',
#    'f588c8d4-ae74-5ffa-9657-c0c241263b8e_2',
#    {'property': 'location'}],
#   ['f588c8d4-ae74-5ffa-9657-c0c241263b8e_1',
#    'did not survive the encounter with',
#    'f588c8d4-ae74-5ffa-9657-c0c241263b8e_4',
#    {'property': 'cause_of_encounter'}],
#   ['f588c8d4-ae74-5ffa-9657-c0c241263b8e_4',
#    'utilized by',
#    'f588c8d4-ae74-5ffa-9657-c0c241263b8e_3',
#    {'property': 'time'}],
#   ['2d0b957e-6b98-55a4-8971-d4b4679b1c87_1',
#    'involved in',
#    '2d0b957e-6b98-55a4-8971-d4b4679b1c87_3',
#    {'description': 'Ukraine agrees to ceasefire'}],
#   ['2d0b957e-6b98-55a4-8971-d4b4679b1c87_2',
#    'involved in',
#    '2d0b957e-6b98-55a4-8971-d4b4679b1c87_3',
#    {'description': 'Russia agrees to ceasefire'}],
#   ['2d0b957e-6b98-55a4-8971-d4b4679b1c87_3',
#    'leads to',
#    '2d0b957e-6b98-55a4-8971-d4b4679b1c87_4',
#    {'description': 'Ceasefire leads to conflict resolution discussion'}],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_1',
#    'accuses',
#    '7e13bbd5-6466-5aed-b952-8019b02dd0bc_2',
#    {'statement': 'Russia officially accuses Ukraine of involvement in the terrorist attack at Crocus.'}],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_1',
#    'demands arrest and extradition of',
#    '7e13bbd5-6466-5aed-b952-8019b02dd0bc_2',
#    {'statement': 'Russia demands the arrest and extradition of all those involved in the terrorist attack.'}],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_1',
#    'demands arrest of',
#    '7e13bbd5-6466-5aed-b952-8019b02dd0bc_5',
#    {'statement': 'Russia demands the arrest of the head of the SBU Malyuk for his alleged involvement in the Crimean Bridge bombing and murder in the Russian Federation.'}],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_5',
#    'involved in',
#    '7e13bbd5-6466-5aed-b952-8019b02dd0bc_6',
#    {'statement': 'SBU Malyuk is stated to be involved in the bombing of the Crimean Bridge.'}],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_5',
#    'involved in',
#    '7e13bbd5-6466-5aed-b952-8019b02dd0bc_7',
#    {'statement': 'SBU Malyuk is stated to be involved in the murder of a number of people in the Russian Federation (in particular Tatarsky).'}],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_4',
#    'issues threat to',
#    '7e13bbd5-6466-5aed-b952-8019b02dd0bc_2',
#    {'statement': 'Russian Foreign Ministry threatens Ukraine with liability for violation of obligations under anti-terrorism conventions.'}],
#   ['7e13bbd5-6466-5aed-b952-8019b02dd0bc_2',
#    'denies involvement in',
#    '7e13bbd5-6466-5aed-b952-8019b02dd0bc_3',
#    {'statement': 'Ukraine denies any involvement in the terrorist attack at Crocus.'}],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_1',
#    'participated in',
#    'c5239a57-f27e-502a-a4fd-fb37c883317b_3',
#    {'Location': 'Sakhalin'}],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_2',
#    'related to',
#    'c5239a57-f27e-502a-a4fd-fb37c883317b_1',
#    {}],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_6',
#    'location of',
#    'c5239a57-f27e-502a-a4fd-fb37c883317b_1',
#    {}],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_6',
#    'location of',
#    'c5239a57-f27e-502a-a4fd-fb37c883317b_11',
#    {}],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_3',
#    'attended by',
#    'c5239a57-f27e-502a-a4fd-fb37c883317b_8',
#    {}],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_3',
#    'attended by',
#    'c5239a57-f27e-502a-a4fd-fb37c883317b_9',
#    {}],
#   ['c5239a57-f27e-502a-a4fd-fb37c883317b_3',
#    'attended by',
#    'c5239a57-f27e-502a-a4fd-fb37c883317b_10',
#    {}],
#   ['96d90f49-ec47-56af-9e51-c7b840f54eff_1',
#    'destroyed',
#    '96d90f49-ec47-56af-9e51-c7b840f54eff_2',
#    {'method': 'precise shot'}],
#   ['96d90f49-ec47-56af-9e51-c7b840f54eff_1',
#    'used',
#    '96d90f49-ec47-56af-9e51-c7b840f54eff_5',
#    {'ammunition': 'Krasnopol'}],
#   ['96d90f49-ec47-56af-9e51-c7b840f54eff_1',
#    'located in',
#    '96d90f49-ec47-56af-9e51-c7b840f54eff_3',
#    {}],
#   ['96d90f49-ec47-56af-9e51-c7b840f54eff_3',
#    'in',
#    '96d90f49-ec47-56af-9e51-c7b840f54eff_4',
#    {}],
#   ['2acaf432-a7ee-5ac5-9ed9-27907cacaea1_1',
#    'is part of',
#    '2acaf432-a7ee-5ac5-9ed9-27907cacaea1_2',
#    {}],
#   ['2acaf432-a7ee-5ac5-9ed9-27907cacaea1_1',
#    'contains',
#    '2acaf432-a7ee-5ac5-9ed9-27907cacaea1_3',
#    {}],
#   ['2acaf432-a7ee-5ac5-9ed9-27907cacaea1_3',
#    'includes',
#    '2acaf432-a7ee-5ac5-9ed9-27907cacaea1_4',
#    {}],
#   ['2acaf432-a7ee-5ac5-9ed9-27907cacaea1_1',
#    'contains',
#    '2acaf432-a7ee-5ac5-9ed9-27907cacaea1_5',
#    {}],
#   ['2acaf432-a7ee-5ac5-9ed9-27907cacaea1_5',
#    'located at',
#    '2acaf432-a7ee-5ac5-9ed9-27907cacaea1_6',
#    {}],
#   ['c9e2da87-1c2d-58fe-ad48-3033050276bd_1',
#    'destroyed',
#    'c9e2da87-1c2d-58fe-ad48-3033050276bd_2',
#    {'method': 'various means of destruction'}],
#   ['c9e2da87-1c2d-58fe-ad48-3033050276bd_2',
#    'was stopped by',
#    'c9e2da87-1c2d-58fe-ad48-3033050276bd_1',
#    {'result': 'enemy assault prevention'}],
#   ['c9e2da87-1c2d-58fe-ad48-3033050276bd_2',
#    'was moving behind',
#    'c9e2da87-1c2d-58fe-ad48-3033050276bd_3',
#    {}],
#   ['c9e2da87-1c2d-58fe-ad48-3033050276bd_3',
#    'retreated from',
#    'c9e2da87-1c2d-58fe-ad48-3033050276bd_1',
#    {'reason': 'enemy tank destruction'}],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_2',
#    'painted',
#    '31455daa-7058-5a72-9531-bfe5b5aee0f1_3',
#    {'description': 'Tube painted by'}],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_3',
#    'depicts',
#    '31455daa-7058-5a72-9531-bfe5b5aee0f1_4',
#    {'description': 'Depicts'}],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_4',
#    'sown by',
#    '31455daa-7058-5a72-9531-bfe5b5aee0f1_5',
#    {'description': 'Sown by'}],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_1',
#    'organizing',
#    '31455daa-7058-5a72-9531-bfe5b5aee0f1_3',
#    {'description': 'Organizing the charity auction of'}],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_1',
#    'collecting funds for',
#    '31455daa-7058-5a72-9531-bfe5b5aee0f1_6',
#    {'description': 'Collecting funds for purchase of'}],
#   ['31455daa-7058-5a72-9531-bfe5b5aee0f1_6',
#    'for defenders of',
#    '31455daa-7058-5a72-9531-bfe5b5aee0f1_7',
#    {'description': 'For defenders of'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_1',
#    'is indignant at',
#    '683fcdec-a977-5367-8583-1828acabc83a_3',
#    {'Reason': 'Issues with production delay'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_1',
#    'has set strict limits for',
#    '683fcdec-a977-5367-8583-1828acabc83a_2',
#    {'Action': 'Control over defense plants'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_1',
#    'needs to take action to address shortage of',
#    '683fcdec-a977-5367-8583-1828acabc83a_5',
#    {'Concern': 'Workers receiving low salary'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_4',
#    'is indignant at',
#    '683fcdec-a977-5367-8583-1828acabc83a_6',
#    {'Problem': 'Examination delay'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_9',
#    'mentioned in',
#    '683fcdec-a977-5367-8583-1828acabc83a_4',
#    {'Comparison': 'Bureaucrats would have been shot'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_10',
#    'reported',
#    '683fcdec-a977-5367-8583-1828acabc83a_11',
#    {'Issue': 'Child with disability'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_12',
#    'can be privately owned or under control of',
#    '683fcdec-a977-5367-8583-1828acabc83a_13',
#    {'Ownership': 'Defense industry enterprises'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_12',
#    'can be influenced by',
#    '683fcdec-a977-5367-8583-1828acabc83a_17',
#    {'Potential Action': 'Sabotage'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_4',
#    'unable to take action against',
#    '683fcdec-a977-5367-8583-1828acabc83a_14',
#    {'Limitation': 'Cannot fire slowing director'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_14',
#    'terminated',
#    '683fcdec-a977-5367-8583-1828acabc83a_15',
#    {'Action': 'Laid off 300 employees'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_16',
#    'may engage in',
#    '683fcdec-a977-5367-8583-1828acabc83a_18',
#    {'Potential Action': 'Sabotage'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_16',
#    'motivated by',
#    '683fcdec-a977-5367-8583-1828acabc83a_19',
#    {'Reason': 'Foreign influence'}],
#   ['683fcdec-a977-5367-8583-1828acabc83a_20',
#    'proposed as solution to enable',
#    '683fcdec-a977-5367-8583-1828acabc83a_4',
#    {'Action': 'Real influence over defense industry plants'}],
#   ['dae4b91a-789d-51ac-ba7f-63e9ab4e78e8_1',
#    'experienced',
#    'dae4b91a-789d-51ac-ba7f-63e9ab4e78e8_2',
#    {'date': 'current'}],
#   ['14a4c38b-558f-5658-a87f-bd0d5b4acdcb_1',
#    'SELLS',
#    '14a4c38b-558f-5658-a87f-bd0d5b4acdcb_2',
#    {'products': ['Xiaomi Robot glass cleaner HUTT DDC EU',
#      'Xiaomi Lydsto G2D EU',
#      'Roborock Q7 Max',
#      'Xiaomi Viomi S9 UV Black V-RVCLMD28C',
#      'Xiaomi Deerma DEM-BY200',
#      'Xiaomi hand vacuum cleaners']}],
#   ['14a4c38b-558f-5658-a87f-bd0d5b4acdcb_1',
#    'OPERATES_IN',
#    '14a4c38b-558f-5658-a87f-bd0d5b4acdcb_2',
#    {'address': '50 years of the USSR, 150 (district of the Covered Market)'}],
#   ['14a4c38b-558f-5658-a87f-bd0d5b4acdcb_1',
#    'OPERATES_IN',
#    '14a4c38b-558f-5658-a87f-bd0d5b4acdcb_3',
#    {'address': 'Gorbachev Blvd., 32 (entrance from Sverdlova St.)'}],
#   ['14a4c38b-558f-5658-a87f-bd0d5b4acdcb_1',
#    'OPERATES_IN',
#    '14a4c38b-558f-5658-a87f-bd0d5b4acdcb_2',
#    {'address': "Shevchenko Blvd., 41D (in the shopping center 'Milk')"}],
#   ['14a4c38b-558f-5658-a87f-bd0d5b4acdcb_1',
#    'OPERATES_IN',
#    '14a4c38b-558f-5658-a87f-bd0d5b4acdcb_2',
#    {'address': "st. Zemlyanskaya, 10B (in the 'Moloko' shopping center)"}],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_1',
#    'presented',
#    '19d200ca-fb01-5f04-9f17-4e7cff621e08_4',
#    {'role': 'War History Weapons host'}],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_2',
#    'participated in',
#    '19d200ca-fb01-5f04-9f17-4e7cff621e08_4',
#    {'role': 'guest'}],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_1',
#    'supports',
#    '19d200ca-fb01-5f04-9f17-4e7cff621e08_5',
#    {'method': "building an electronic warfare system for the soldier's unit"}],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_5',
#    'located in',
#    '19d200ca-fb01-5f04-9f17-4e7cff621e08_6',
#    {}],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_3',
#    'is a version of',
#    '19d200ca-fb01-5f04-9f17-4e7cff621e08_4',
#    {}],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_3',
#    'located in',
#    '19d200ca-fb01-5f04-9f17-4e7cff621e08_5',
#    {}],
#   ['19d200ca-fb01-5f04-9f17-4e7cff621e08_3',
#    'located in',
#    '19d200ca-fb01-5f04-9f17-4e7cff621e08_6',
#    {}],
#   ['4636768e-14e6-5844-98e0-211e7a450519_1',
#    'conducts strikes on',
#    '4636768e-14e6-5844-98e0-211e7a450519_2',
#    {'action': 'massive'}],
#   ['4636768e-14e6-5844-98e0-211e7a450519_2',
#    'is located in',
#    '4636768e-14e6-5844-98e0-211e7a450519_3',
#    {}],
#   ['4636768e-14e6-5844-98e0-211e7a450519_4',
#    'mentions',
#    '4636768e-14e6-5844-98e0-211e7a450519_3',
#    {'hashtag': 'Syria'}],
#   ['f381cb04-0776-5651-b432-9d88cd65a3e6_1',
#    'uses',
#    'f381cb04-0776-5651-b432-9d88cd65a3e6_2',
#    {'description': 'homemade ammunition'}],
#   ['f381cb04-0776-5651-b432-9d88cd65a3e6_1',
#    'uses',
#    'f381cb04-0776-5651-b432-9d88cd65a3e6_3',
#    {'description': 'Baba Yaga drone'}],
#   ['f381cb04-0776-5651-b432-9d88cd65a3e6_4',
#    'mentioned in post by',
#    'f381cb04-0776-5651-b432-9d88cd65a3e6_1',
#    {'description': 'mentioned in the post'}],
#   ['16aeba2a-8489-5d3e-bfde-b65a8c898ccd_1',
#    'approved operational plans for',
#    '16aeba2a-8489-5d3e-bfde-b65a8c898ccd_3',
#    {'Information': 'Current offensive plans'}],
#   ['16aeba2a-8489-5d3e-bfde-b65a8c898ccd_3',
#    'is located in',
#    '16aeba2a-8489-5d3e-bfde-b65a8c898ccd_2',
#    {'Information': 'Southern part of the enclave'}],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_1',
#    'took to the streets in',
#    '4cd09aad-8ef1-5e18-bc59-3a947e061e5c_2',
#    {}],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_1',
#    'took to the streets in',
#    '4cd09aad-8ef1-5e18-bc59-3a947e061e5c_3',
#    {}],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_1',
#    'demanding the resignation of',
#    '4cd09aad-8ef1-5e18-bc59-3a947e061e5c_4',
#    {}],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_1',
#    'demanding a deal to free',
#    '4cd09aad-8ef1-5e18-bc59-3a947e061e5c_5',
#    {}],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_6',
#    'shows',
#    '4cd09aad-8ef1-5e18-bc59-3a947e061e5c_7',
#    {}],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_7',
#    'marched to',
#    '4cd09aad-8ef1-5e18-bc59-3a947e061e5c_8',
#    {}],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_7',
#    'demanded the resignation of',
#    '4cd09aad-8ef1-5e18-bc59-3a947e061e5c_10',
#    {}],
#   ['4cd09aad-8ef1-5e18-bc59-3a947e061e5c_11',
#    'subscribe to',
#    '4cd09aad-8ef1-5e18-bc59-3a947e061e5c_11',
#    {}],
#   ['1aa793cd-f09d-5a4e-8946-5b7b60e71f42_1',
#    'participated in',
#    '1aa793cd-f09d-5a4e-8946-5b7b60e71f42_2',
#    {'context': 'demanding the return of hostages held in the Gaza Strip'}],
#   ['1aa793cd-f09d-5a4e-8946-5b7b60e71f42_2',
#    'reported by',
#    '1aa793cd-f09d-5a4e-8946-5b7b60e71f42_5',
#    {'source': 'Bild'}],
#   ['1aa793cd-f09d-5a4e-8946-5b7b60e71f42_3',
#    'involved in',
#    '1aa793cd-f09d-5a4e-8946-5b7b60e71f42_2',
#    {}],
#   ['1aa793cd-f09d-5a4e-8946-5b7b60e71f42_4',
#    'location',
#    '1aa793cd-f09d-5a4e-8946-5b7b60e71f42_3',
#    {}]]}

# %%
with open('graph_50_deduped.json', 'w+') as file:
    json.dump(structured_data, file, indent = 4)

# %%
def create_graph(data):
    G = nx.DiGraph()
    for node in data['subjects']:
        node_id, name, node_type = node
        G.add_node(node_id, name = name, node_type = node_type)
        
    for edge in data['relationships']:
        source, relation, target, props = edge
        G.add_edge(source, target, relation=relation)
    return G

def draw_graph(G):
    pos = nx.spring_layout(G)
    nx.draw_networkx_nodes(G, pos, node_size=100, node_color='lightblue', alpha=0.6)
    nx.draw_networkx_edges(G, pos, arrowstyle='-|>', arrowsize=5, edge_color='gray', width=2)
    node_labels = {node: G.nodes[node]['name'] for node in G.nodes()}
    nx.draw_networkx_labels(G, pos, labels=node_labels, font_size=12)
    edge_labels = {(u, v): data['relation'] for u, v, data in G.edges(data=True)}
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')
    plt.title('Graph Visualization')
    plt.axis('off')
    plt.show()

# %%
G = create_graph(structured_data)

# %%
import difflib
from collections import defaultdict

# Function to group nodes by name similarity
def group_similar_nodes(graph, cutoff=0.8):
    names = nx.get_node_attributes(graph, 'name')
    nodes = sorted(names, key=lambda x: names[x])
    clusters = []
    used = set()

    for node in nodes:
        if node not in used:
            cluster = {node}
            for other in nodes:
                if other not in used and difflib.SequenceMatcher(None, names[node], names[other]).ratio() >= cutoff:
                    cluster.add(other)
            clusters.append(cluster)
            used.update(cluster)

    return clusters

# Function to merge nodes
def merge_nodes(graph, clusters):
    new_graph = nx.DiGraph()
    for cluster in clusters:
        # Concatenate names of all nodes in the cluster
        merged_name = ' ; '.join(set(graph.nodes[n]['name'] for n in cluster))
        node_type = ' ; '.join(set(graph.nodes[n]['node_type'] for n in cluster))
        new_node = min(cluster)  # Use the smallest node ID in the cluster as the new node ID

        new_graph.add_node(new_node, name=merged_name, node_type = node_type)

        # Merging edges and their attributes
        edge_attributes = defaultdict(set)
        for old_node in cluster:
            for neighbor, attrs in graph[old_node].items():
                if neighbor not in cluster:
                    edge_attributes[(new_node, neighbor)].add(attrs['relation'])

        # Add merged edges with combined attributes to the new graph
        for (u, v), relations in edge_attributes.items():
            new_graph.add_edge(u, v, relation=list(relations))

    return new_graph

# Find clusters of similar nodes and merge them
clusters = group_similar_nodes(G)
new_G = merge_nodes(G, clusters)

# %%
nx.write_gml(new_G, 'test1.gml')

# %%
def graph_to_custom_json(graph):
    # Only include nodes that have a 'name' attribute
    subjects = [[node, graph.nodes[node]['name'], 'single_type'] for node in graph.nodes() if 'name' in graph.nodes[node]]
    
    # Prepare relationships, making sure both nodes in the edge have 'name' attributes
    relationships = [[u, graph.edges[u, v]['relation'], v, graph.edges[u, v].get('properties', {})]
                     for u, v in graph.edges() if 'name' in graph.nodes[u] and 'name' in graph.nodes[v]]

    return {
        "subjects": subjects,
        "relationships": relationships
    }

# Assuming 'new_G' is your graph object post-processing
custom_data = graph_to_custom_json(new_G)

# Save the JSON object to a file
with open('graph_50_deduped.json', 'w') as f:
    json.dump(custom_data, f, indent=4)

print("Graph saved in custom JSON format.")
# Out:
# Graph saved in custom JSON format.

# %%
new_G

# %%
def compute_graph_metrics(graph):
    # Ensure the graph is a directed graph; adapt as necessary for undirected graphs
    if not graph.is_directed():
        raise ValueError("Input graph must be directed. For undirected graphs, modify the function accordingly.")

    # Calculate metrics
    in_degrees = dict(graph.in_degree())  # In-degree
    out_degrees = dict(graph.out_degree())  # Out-degree
    try:
        eigenvector_centrality = nx.eigenvector_centrality_numpy(graph)  # Eigenvector centrality
    except nx.NetworkXError as e:
        print("Error calculating eigenvector centrality:", e)
        eigenvector_centrality = {n: 0 for n in graph.nodes()}  # Default to 0 if calculation fails

    # Component ID assignment using weakly connected components
    components = list(nx.weakly_connected_components(graph))
    component_dict = {node: idx for idx, component in enumerate(components) for node in component}

    # Create DataFrame
    data = {
        'Node': list(graph.nodes()),
        'In-Degree': [in_degrees.get(node) for node in graph.nodes()],
        'Out-Degree': [out_degrees.get(node) for node in graph.nodes()],
        'Eigenvector Centrality': [eigenvector_centrality.get(node, 0.0) for node in graph.nodes()],
        'Component ID': [component_dict.get(node, -1) for node in graph.nodes()]
    }
    df = pd.DataFrame(data)
    return df

# %%
compute_graph_metrics(new_G).to_csv('graph_50_deduped_nodes.csv', index = False)
